# %% [markdown]
# # Introduction to Anaconda

# %% [markdown]
# Ref: https://www.anaconda.com/,
# <br>
# Ref: https://www.youtube.com/watch?v=9mAmZIRfJBs

# %% [markdown]
# Anaconda is a platform or an IDE (Integrated Development Environment) to use Python for developing large scale projects.
# <br>
# These could be data science projects, web projects, standalone applications using Python. The advantage of using Anaconda is that it hosts several tools at one place for everyone to use.

# %% [markdown]
# ## How does it look like?

# %%
from IPython.display import Image
Image(filename='images\\anaconda_ui.png')

# %% [markdown]
# The applications shown above might change depending on which version of Anaconda you install; also you might have to click 'Install' on the application to actually install it (Not all applications are installed in order to save space)

# %% [markdown]
# ## How to start it?

# %%
from IPython.display import Image
Image(filename='images\\anaconda_navigator.png')

# %% [markdown]
# Search for 'anaconda-navigator' in Windows search tab and start the application.

# %% [markdown]
# ## How to use it?

# %% [markdown]
# ### Jupyterlab

# %% [markdown]
# Click 'Launch' on the Jupyterlab tab.

# %%
from IPython.display import Image
Image(filename='images\\jupyterlab_icon.jpg')

# %%
from IPython.display import Image
Image(filename='images\\jupyterlab_notebook.png')
